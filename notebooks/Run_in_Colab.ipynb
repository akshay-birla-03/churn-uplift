# %% [markdown]
# # Churn Uplift — one-click run
#
# This notebook clones the repository, installs it, and runs the demo end-to-end. **Runtime → Run all**.
#
# Runs fully on the free Colab CPU runtime — no API keys, no data downloads (all demo data is generated in code).

# %% [markdown]
# ### 1. Clone the repository

# %%
import os
if not os.path.isdir('/content/churn-uplift'):
    # !git clone -q https://github.com/akshay-birla-03/churn-uplift.git /content/churn-uplift
# %cd /content/churn-uplift

# %% [markdown]
# ### 2. Install

# %%
# !pip install -q -e .

# %% [markdown]
# ### 3. Run the demo

# %%
# !upliftkit -n 4000
